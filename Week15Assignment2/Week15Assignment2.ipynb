# %% [markdown]
# <a href="https://colab.research.google.com/github/nesmario5222/PythonLMAO/blob/main/Week15Assignment2/Week15Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import os

FILE = "expenses.json"

def load_data():
    if os.path.exists(FILE):
        with open(FILE, "r") as f:
            return json.load(f)
    return []

def save_data(data):
    with open(FILE, "w") as f:
        json.dump(data, f)

def add_expense(data):
    name = input("Expense name: ")
    amount = float(input("Amount: "))
    category = input("Category: ")

    data.append({
        "name": name,
        "amount": amount,
        "category": category
    })

    save_data(data)

def view_expenses(data):
    for e in data:
        print(f"{e['name']} - ${e['amount']} ({e['category']})")

def total_spending(data):
    total = sum(e["amount"] for e in data)
    print(f"Total spending: ${total}")

def main():
    data = load_data()

    while True:
        print("\n1. Add Expense")
        print("2. View Expenses")
        print("3. Total Spending") # Moved inside main loop
        print("4. Exit") # Moved inside main loop

        choice = input("Choice: ")

        if choice == "1":
            add_expense(data)
        elif choice == "2":
            view_expenses(data)
        elif choice == "3": # Integrated into the main loop's conditional logic
            total_spending(data)
        elif choice == "4": # Integrated into the main loop's conditional logic
            break

main()
# Out:
# 1. Add Expense
# 2. View Expenses
# 3. Total Spending
# 4. Exit
# Choice: 2
# Mario - $2500.0 (Video Games)
#
# 1. Add Expense
# 2. View Expenses
# 3. Total Spending
# 4. Exit
# Choice: 3
# Total spending: $2500.0
#
# 1. Add Expense
# 2. View Expenses
# 3. Total Spending
# 4. Exit
# Choice: 1
# Expense name: Sonic
# Amount: 1500
# Category: Video Games
#
# 1. Add Expense
# 2. View Expenses
# 3. Total Spending
# 4. Exit
# Choice: 2
# Mario - $2500.0 (Video Games)
# Sonic - $1500.0 (Video Games)
#
# 1. Add Expense
# 2. View Expenses
# 3. Total Spending
# 4. Exit
# Choice: 3
# Total spending: $4000.0
#
# 1. Add Expense
# 2. View Expenses
# 3. Total Spending
# 4. Exit
# Choice: 4
