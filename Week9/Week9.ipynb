# %% [markdown]
# <a href="https://colab.research.google.com/github/nesmario5222/PythonLMAO/blob/main/Week9/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rentalcar.py

def calculate_bill(classification, miles, days):
    charged_miles = 0
    total_bill = 0
    return charged_miles, total_bill

# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
# calculate_bill(classification, miles, days)
#   determine rate and free miles
#   calculate charged miles
#   calculate total cost
#   return charged miles and total bill

# PROGRAM LOGIC
# ask user for classification code (B, S, L)
# ask for start odometer
# ask for end odometer
# ask for days rented
# calculate miles driven
# call calculate_bill function
# print rental summary

while True:
    classification = input("Enter classification code (B, S, L): ")
    if classification in ["B", "S", "L"]:
        break
    else:
        print("Invalid code. Please enter B, S, or L.")

start_odometer = int(input("Start Odometer: "))
end_odometer = int(input("End Odometer: "))
days = int(input("Days Rented: "))
total_miles = end_odometer - start_odometer
charged_miles, total_bill = calculate_bill(classification, total_miles, days)

print("--- RENTAL SUMMARY ---")
print("Classification:", classification)
print("Total Miles:", total_miles)
# Out:
# Enter classification code (B, S, L): B
# Start Odometer: 60
# End Odometer: 100
# Days Rented: 4
# --- RENTAL SUMMARY ---
# Classification: B
# Total Miles: 40
