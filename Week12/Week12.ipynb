# %% [markdown]
# <a href="https://colab.research.google.com/github/nesmario5222/PythonLMAO/blob/main/Week12/Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rectangle.py
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS

    # calculate area using length * width
    # calculate perimeter using 2 * (length + width)
    # pack both values into a tuple (area, perimeter)
    # return the tuple

# PROGRAM LOGIC
