# %% [markdown]
# <a href="https://colab.research.google.com/github/nesmario5222/PythonLMAO/blob/main/Week2/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"Print the total minutes in a movie (2 * 60 + 45)"
print(2*60+45)
"Print the years since 1947 (2026 - 1947)."
print(2026 - 1947)
# Out:
# 165
# 79
