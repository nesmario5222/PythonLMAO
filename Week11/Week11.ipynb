# %% [markdown]
# <a href="https://colab.research.google.com/github/nesmario5222/PythonLMAO/blob/main/Week11/Week11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: gradebook.py
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS

def add_students(gradebook):
    while True:
        name = input("Enter student name (or 'done'): ")

        if name.lower() == "done":
            break

        grade = int(input(f"Enter {name}'s grade: "))
        gradebook[name] = grade


def calculate_average(gradebook):
    pass

def calculate_average(gradebook):
    if len(gradebook) == 0:
        return 0

    total = sum(gradebook.values())
    average = total / len(gradebook)
    return average


    # Use a while loop
    # Ask user for student name
    # If user enters "done", exit loop
    # Otherwise ask for grade (0–100)
    # Store name as key and grade as value in dictionary



    # Get all grades using .values()
    # If dictionary is empty, return 0
    # Otherwise calculate average = sum / number of students
    # Return the average



# PROGRAM LOGIC

# Create empty dictionary called gradebook
# Call add_students to fill dictionary
# Call calculate_average and store result
# Print each student's name and grade
# Print class average formatted to 2 decimal places

gradebook = {}

add_students(gradebook)

average = calculate_average(gradebook)

print("--- Class Report ---")
for student, grade in gradebook.items():
    print(f"{student}: {grade}")

print(f"Class Average: {average:.2f}")
# Out:
# Enter student name (or 'done'): Mario
# Enter Mario's grade: 100
# Enter student name (or 'done'): Luigi
# Enter Luigi's grade: 99
# Enter student name (or 'done'): done
# --- Class Report ---
# Mario: 100
# Luigi: 99
# Class Average: 99.50
