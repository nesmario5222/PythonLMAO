# %% [markdown]
# <a href="https://colab.research.google.com/github/nesmario5222/PythonLMAO/blob/main/Week3/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Statements

#Function Definitions

#Assign values to name, goal, birth_year, current_year.
name = "Minoru Mineta"
goal = "get all the ladies"
birth_year = 2002
current_year = 2026
#Calculate age.
age = current_year - birth_year
#Print the top border line using string multiplication.
print("="*25)
#Print the bio sentences.
print("My name is " + name + " and I am " + str(age) + " years old. " + "My goal is to " + goal + ".")
#Print the bottom border line using string multiplication.
print("="*25)
# Out:
# ...
# My name is Minoru Mineta and I am 24 years old. My goal is to get all the ladies.
# ...
