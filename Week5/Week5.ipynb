# %% [markdown]
# <a href="https://colab.research.google.com/github/nesmario5222/PythonLMAO/blob/main/Week5/Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define calculate_ticket(age, hour)
def calculate_ticket(age, hour):
    # 2. Logic: If age <= 12 or age >= 65, price = 8. Otherwise, price = 12.
    if age <= 12 or age >= 65:
        price = 8
    else:
        price = 12
    # 3. Logic: If hour < 17, subtract 2 from the price.
    if hour < 17:
        price -= 2
    # 4. Print the final price.
    print("Your ticket price is" ,"$", price )


# PROGRAM LOGIC
# 1. input() for age (int)
age_input = int(input("Enter your age: "))
# 2. input() for movie hour (int)
hour_input = int(input("Enter the movie hour (0-23): "))
# 3. Call calculate_ticket()
calculate_ticket(age_input, hour_input)
# Out:
# Enter your age: 25
# Enter the movie hour (0-23): 11
# Your ticket price is $ 10
