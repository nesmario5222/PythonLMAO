# %% [markdown]
# <a href="https://colab.research.google.com/github/nesmario5222/PythonLMAO/blob/main/Week4/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
# 1. Define print_bio with three parameters: name, age, and goal.
def print_bio(name, age, goal):
    # 2. Inside the function, use string multiplication (*) for a border line.
    print("*" * 25)
    # 3. Print the bio details using the parameter names.
    print("Name:", name, "Age:", age, "Goal:", goal)
    print("*" * 25)

# PROGRAM LOGIC
# 1. Call print_bio using my own info.
# 2. Call print_bio using [Name of Famous Person].
# 3. Call print_bio using [Name of Fictional Character].
print_bio("Jayvin", 16, "Reach 2000 elo in Chess")
print_bio("Marie Curie", 66, "Discover two new elements")
print_bio("Mario", 25, "Save Princess Peach and stop Bowser")
# Out:
# *************************
# Name: Jayvin Age: 16 Goal: Reach 2000 elo in Chess
# *************************
# *************************
# Name: Marie Curie Age: 66 Goal: Discover two new elements
# *************************
# *************************
# Name: Mario Age: 25 Goal: Save Princess Peach and stop Bowser
# *************************
